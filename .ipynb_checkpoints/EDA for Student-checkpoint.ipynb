# %% [markdown]
# # Problem Statement:
#
#     gender                       : Gender of the student
#     race/ethnicity               : Race of the Student As Group A/B/C
#     parental level of education  : What is the education Qualification of Students Parent
#     lunch                        : Whether the lunch is Standard type/Free lunch or Some discounted lunch
#     test preparation course      : Whether Student has Taken or not and Completed
#     math score                   : Scores in Maths
#     reading score                : Scores in Reading
#     writing score                : Scores in Writing
#
# Objective of this Analysis:
#
#     To understand the how the student's performance (test scores) is affected by the other variables (Gender, Ethnicity, Parental level of education, Lunch, Test preparation course).
#
# What to do in  Exploratory Data Analysis:
#
# 1. To Analyse insights in the data set.
# 2. To understand the connection between the variables and to uncover the underlying structure
# 3. To extract the important Variables.
# 4. To test the underlying assumptions.
# 5. Provide Insights with Suitable Graphs and Visualizations.
# 6. Write all your inferences with supporting Analysis and Visualizations.

# %%
#importing numpy and pandas
import pandas as pd
import numpy as np

# %%
student_dataset = pd.read_csv('StudentsPerformance.csv')
student_dataset.shape
# Out:
# (1000, 8)

# %% [markdown]
# So, It shows us that the dataset has 1000 records/rows and 8 columns

# %%
student_dataset.head(1000)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student_dataset.columns.tolist()
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course',
#  'math score',
#  'reading score',
#  'writing score']

# %% [markdown]
# This is the list of columns present in the dataset.

# %%
#printing all the unique values for each column.

print('Gender:',student_dataset.gender.unique(),'\n')

print('race/ethnicity:',student_dataset['race/ethnicity'].unique(),'\n')

print('parental level of education:',student_dataset['parental level of education'].unique(),'\n')

print('lunch:',student_dataset['lunch'].unique(),'\n')

print('test preparation course:',student_dataset['test preparation course'].unique(),'\n')

print('math score:',student_dataset['math score'].unique(),'\n')

print('reading score:',student_dataset['reading score'].unique(),'\n')

print('writing score:',student_dataset['writing score'].unique(),'\n')
# Out:
# Gender: ['female' 'male']
#
# race/ethnicity: ['group B' 'group C' 'group A' 'group D' 'group E']
#
# parental level of education: ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
#
# lunch: ['standard' 'free/reduced']
#
# test preparation course: ['none' 'completed']
#
# math score: [ 72  69  90  47  76  71  88  40  64  38  58  65  78  50  18  46  54  66
#   44  74  73  67  70  62  63  56  97  81  75  57  55  53  59  82  77  33
#   52   0  79  39  45  60  61  41  49  30  80  42  27  43  68  85  98  87
#   51  99  84  91  83  89  22 100  96  94  48  35  34  86  92  37  28  24
#   26  95  36  29  32  93  19  23   8]
#
# reading score: [ 72  90  95  57  78  83  43  64  60  54  52  81  53  75  89  32  42  58
#   69  73  71  74  70  65  87  56  61  84  55  44  41  85  59  17  39  80
#   37  63  51  49  26  68  45  47  86  34  79  66  67  91 100  76  77  82
# ...

# %% [markdown]
# - Observations: -
#     1.	Gender has only two unique values i.e. Male and Female.
#     2.	Race contains 5 groups i.e. group A, group B, group C, group D, group E.
#     3.	Parental level of education is different for students and listed as follows:
#         -	Bachelor’s degree
#         -	Some college
#         -	Master’s degree
#         -	Associate’s degree
#         -	High school
#         -	Some High school
#     4.	Lunch type has only two unique value i.e. standard and free/reduced.
#     5.	Test preparation course also has two unique value none and completed. So, no student has on going test preparation course.
#     6.	Math, Reading and Writing score has so many unique values. We will look all this values and their counts in graph below.

# %%
student_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# It shows the summary of the dataset.
# It contains all the names of the columns and shows the count of the non-null values and datatype of each column.
#     So, we can say that there is no null record in the dataset.

# %%
student_dataset.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# It shows the statistics of the dataset.
#     It shows us the count of null/non-null observation, mean and standard deviation of all the score, minimum and maximum score
#     in math, reading and writing. Further shows us the 3 quantiles of the data(25%, 50%, 75%).

# %%
student_dataset.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# So, we can see that there is no null record.

# %%
student_dataset.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#importing seaborn and mathplotlib for plotting graphs
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(x = 'math score' , data = student_dataset , palette = 'Set1')
plt.title('Math Score',fontsize = 20)
plt.show()

# %% [markdown]
# Above graph shows the Math score count of the Students.

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(x = 'reading score' , data = student_dataset , palette = 'dark')
plt.title('Reading Score',fontsize = 20)
plt.show()

# %% [markdown]
# Above graph shows the reading score count of the Students.

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(x = 'writing score' , data = student_dataset , palette = 'prism')
plt.title('Writing Score',fontsize = 20)
plt.show()

# %% [markdown]
# Above graph shows the writing score count of the Students.

# %%
#plotting KDE
student_dataset.plot.density()

# %% [markdown]
# - Observations: -
#     1.	Peak point/Mean of Reading and Writing score is almost same.

# %% [markdown]
# But for much clear view let's plot the same using violin plot.

# %%
plt.figure(figsize = (15,5))
plt.subplots_adjust(left = 0.125 , bottom = 0.1 , right = 0.9 , top = 0.9 , wspace = 0.5 , hspace = 0.2)

plt.subplot(141)
plt.title('Math Scores')
sns.violinplot(y = 'math score' , data = student_dataset , color = 'r' , linewidth = 2)

plt.subplot(142)
plt.title('Reading Scores')
sns.violinplot(y = 'reading score' , data = student_dataset , color = 'b' , linewidth = 2)

plt.subplot(143)
plt.title('Writing Scores')
sns.violinplot(y = 'writing score' , data = student_dataset , color = 'g' , linewidth = 2)

plt.show()

# %% [markdown]
# - Observations: -
#     1.	Most of the students are scoring between 60-80 in Math, Reading and Writing.

# %% [markdown]
# Now Let us observe the remaining columns/attributes using pie chart.
# Drawing pie chart will give the information or percentage occupied from the total.

# %%
plt.figure(num = 5 , figsize = (20,10))
plt.subplots_adjust(left = 0.125 , bottom = 0.1 , right = 0.9 , top = 0.9 , wspace = 0.5 , hspace = 0.2)

plt.subplot(141)
plt.title('Gender' , fontsize = 20)
ax1 = student_dataset['gender'].value_counts().plot.pie(autopct = "%1.1f%%")
ax1.set_ylabel('') #for removing label on y-axis

plt.subplot(142)
plt.title('Race/Ethinicity' , fontsize = 20)
ax2 = student_dataset['race/ethnicity'].value_counts().plot.pie(autopct = "%1.1f%%")
ax2.set_ylabel('')

plt.subplot(143)
plt.title('Lunch' , fontsize = 20)
ax3 = student_dataset['lunch'].value_counts().plot.pie(autopct = "%1.1f%%")
ax3.set_ylabel('')

plt.subplot(144)
plt.title('Parentel level of Education',fontsize = 20)
ax4 = student_dataset['parental level of education'].value_counts().plot.pie(autopct = "%1.1f%%")
ax4.set_ylabel('')

plt.show()

plt.subplot(141)
plt.title('Test Preparation Course' , fontsize = 20)
ax5 = student_dataset['test preparation course'].value_counts().plot.pie(autopct = "%1.1f%%" , radius = 0.7)
ax5.set_ylabel('')

plt.show()

# %% [markdown]
# - Observations: -
#     1.	Female students are slightly more than Male students.
#     2.	Race/Ethnicity group C has highest portion followed by group D, B, E, and A.
#     3.	More than 50% of the students are having standard lunch and remaining are having free/reduced type of lunch.
#     4.	Highest proportion of the parents have some college, associate’s degree, and high school level of education.
#     5.	Highest proportion of the students are not having any test preparation course and remaining have completed their   course.

# %%
#plotting individual score against gender

plt.figure(figsize = (15,5))
plt.subplots_adjust(left = 0.125 , bottom = 0.1 , right = 0.9 , top = 0.9 , wspace = 0.5 , hspace = 0.2)

plt.subplot(131)
plt.title('Math Scores')
sns.barplot(x = "gender" , y = "math score" , data = student_dataset)

plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(x = "gender" , y = "reading score" , data = student_dataset)

plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(x = "gender" , y = "writing score" , data = student_dataset)

plt.show()

# %% [markdown]
# - Observations: -
#     1.	Males students are getting higher score in Math compared to females.
#     2.	Females students are getting higher score in Reading and writing compared to males.

# %%
#plotting individual score against race/ethnicity w.r.t gender

plt.figure(figsize = (15,5))
plt.subplots_adjust(left = 0.125 , bottom = 0.1 , right = 0.9 , top = 0.9 , wspace = 0.5 , hspace = 0.2)

plt.subplot(131)
plt.title('Math Scores')
sns.barplot(hue = "gender" , y = "race/ethnicity" , x = "math score" , data = student_dataset)

plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(hue = "gender" , y = "race/ethnicity" , x = "reading score" , data = student_dataset)

plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(hue = "gender" , y = "race/ethnicity" , x = "writing score" , data = student_dataset)

plt.show()

# %% [markdown]
# - Observations: -
#     1.	Students of group E are scoring more than others and which is followed by group D.

# %%
#plotting individual score against parental level of education w.r.t gender

plt.figure(figsize = (15,5))
plt.subplots_adjust(left = 0.125 , bottom = 0.1 , right = 0.9 , top = 0.9 , wspace = 0.5 , hspace = 0.2)

plt.subplot(131)
plt.title('Math Scores')
sns.barplot(hue = "gender" , y = "parental level of education" , x = "math score" , data = student_dataset)

plt.subplot(132)
plt.title('Reading Scores')
ax1 = sns.barplot(hue = "gender" , y = "parental level of education" , x = "reading score" , data = student_dataset)
ax1.set_ylabel('')#to remove label on y-axis

plt.subplot(133)
plt.title('Writing Scores')
ax2 = sns.barplot(hue = "gender" , y = "parental level of education" , x = "writing score" , data = student_dataset)
ax2.set_ylabel('')

plt.show()

# %% [markdown]
# - Observations: -
#     1.	Parental level of education being Master’s, Bachelor’s and Associate’s degree are scoring more.
#     2.	Parental level of education being high school and some high school are scoring less.
#     3.	Parental level of education being some college are scoring average or intermediate.

# %%
#plotting individual score against lunch w.r.t gender

plt.figure(figsize = (15,5))
plt.subplots_adjust(left = 0.125 , bottom = 0.1 , right = 0.9 , top = 0.9 , wspace = 0.5 , hspace = 0.2)

plt.subplot(131)
plt.title('Math Scores')
sns.barplot(hue = "gender" , x = "lunch" , y = "math score" , data = student_dataset)

plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(hue = "gender" , x = "lunch" , y = "reading score" , data = student_dataset)

plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(hue = "gender" , x = "lunch" , y = "writing score" , data = student_dataset)

plt.show()

# %% [markdown]
# - Observations: -
#     1.	Students having lunch type standard are scoring more than free/reduced lunch type.

# %%
#plotting individual score against test preparation course w.r.t gender

plt.figure(figsize = (15,5))
plt.subplots_adjust(left = 0.125 , bottom = 0.1 , right = 0.9 , top = 0.9 , wspace = 0.5 , hspace = 0.2)

plt.subplot(131)
plt.title('Math Scores')
sns.barplot(hue = "gender" , x = "test preparation course" , y = "math score" , data = student_dataset)

plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(hue = "gender" , x = "test preparation course" , y = "reading score" , data = student_dataset)

plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(hue = "gender" , x = "test preparation course" , y = "writing score" , data = student_dataset)

plt.show()

# %% [markdown]
# - Observations: -
#     1.	Students who have completed the test preparation course are scoring more.

# %%
#plotting individual score against race/ethnicity w.r.t test preparation course

plt.figure(figsize = (15,5))
plt.subplots_adjust(left = 0.125 , bottom = 0.1 , right = 0.9 , top = 0.9 , wspace = 0.5 , hspace = 0.2)

plt.subplot(131)
plt.title('Math Scores')
sns.barplot(hue = "test preparation course" , x = "math score" , y = "race/ethnicity" , data = student_dataset)

plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(hue = "test preparation course" , x = "reading score" , y = "race/ethnicity" , data = student_dataset)

plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(hue = "test preparation course" , x = "writing score" , y = "race/ethnicity" , data = student_dataset)

plt.show()

# %% [markdown]
# - Observations: -
#     1.	Students who belong to group E and has completed the test preparation course in Math and Reading are scoring
#     highest in it.
#     2.	Students who belong to group D & E and has completed the test preparation course in Writing are scoring highest.

# %%
#plotting graph for Test Preparation course with other attributes

plt.figure(figsize = (30,20))
plt.subplots_adjust(left = 0.125 , bottom = 0.1 , right = 0.9 , top = 0.9 , wspace = 0.5 , hspace = 0.2)

plt.subplot(251)
plt.title('Test Preparation Course Vs Gender',fontsize = 15)
sns.countplot(hue = "test preparation course" , x = "gender" , data = student_dataset)

plt.subplot(252)
plt.title('Test Preparation Course Vs Race/Ethnicity',fontsize = 15)
sns.countplot(hue = "test preparation course" , y = "race/ethnicity" , data = student_dataset)

plt.subplot(253)
plt.title('Test Preparation Course Vs Lunch',fontsize = 15)
sns.countplot(hue = "test preparation course" , x = "lunch" , data = student_dataset)

plt.subplot(254)
plt.title('Test Preparation Course Vs Parental Level Of Education',fontsize = 15)
sns.countplot(hue = "test preparation course" , y = "parental level of education" , data = student_dataset)

plt.show()

# %% [markdown]
# - Observations: -
#     1.	Most of the students has not taken/completed the Test Preparation course.
#     2.	Highest number of students who has completed the test preparation course belong to group C and D.
#     3.	Since students of group E has not completed the test preparation course still they are able to score the highest
#     in Math, Reading and Writing all 3.
#     4.	Most of the students who has completed the test preparation course are having Standard lunch type.
#     5.	Most of the Students whose parental level of education is Associate’s degree,  Some college and Some high school
#     has completed the test preparation course. But parents with better degrees didn't send them for any test preparation
#     course. So maybe they believe in self studies.

# %%
plt.figure(figsize = (10,10))

plt.title('Gender Vs Race/Ethnicity' , fontsize = 20)
sns.countplot(hue = "gender", y = "race/ethnicity" , data = student_dataset)
plt.show()

# %% [markdown]
# - Observations: -
#     1.	Group B and C has more number Females than rest of the group.
#     2.  Group A has more number of Male students. (I mean there is a large difference in number than rest of the groups.)

# %%
plt.rcParams['figure.figsize'] = (20, 10)
pr = pd.crosstab(student_dataset['race/ethnicity'] , student_dataset['parental level of education'] , normalize = 0)

pr.plot.bar(stacked = True)
plt.title('Race/Ethinicity Vs Parental Level of Education' , fontsize = 20)
plt.show()

# %% [markdown]
# - Observations: -
#     1.	Parents of group E are more educated than others.

# %%
plt.figure(figsize = (40,10))
plt.subplots_adjust(left = 0.125 , bottom = 0.1 , right = 0.9 , top = 0.9 , wspace = 0.5 , hspace = 0.2)

plt.subplot(251)
plt.title('Lunch Vs Gender' , fontsize = 15)
sns.countplot(x = "lunch" , hue = "gender" , data = student_dataset)

plt.subplot(252)
plt.title('Ethinicity Vs Lunch',fontsize=15)
sns.countplot(x = "race/ethnicity" , hue = "lunch" , data = student_dataset)
plt.show()

# %% [markdown]
# As we saw earlier most of the student are having standard lunch type, irrespective to the group they belong to.

# %%
plt.figure(figsize = (15,5))
plt.subplots_adjust(left = 0.125 , bottom = 0.1 , right = 0.9 , top = 0.9 , wspace = 0.5 , hspace = 0.2)

plt.subplot(131)
plt.title('Parental education level Vs Student Gender' , fontsize = 15)
sns.countplot(y = "parental level of education" , hue = "gender" , data = student_dataset)

plt.subplot(132)
plt.title('Parental education level Vs Lunch' , fontsize = 15)
ax = sns.countplot(y = "parental level of education" , hue = "lunch" , data = student_dataset)
ax.set_ylabel('')

plt.subplot(133)
plt.title('Parental education level Vs Race/Ethnicity' , fontsize = 15)
sns.countplot(hue = "parental level of education" , y = "race/ethnicity" , data = student_dataset)

plt.show()

# %% [markdown]
# # Assigning Grades for better Analysis

# %%
#Adding new column named Total
student_dataset['Total'] = student_dataset['math score'] + student_dataset['reading score'] +student_dataset['writing score']
student_dataset.head(1000)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total
# ...

# %%
#Adding new column name Percentage
student_dataset['Percentage'] = (student_dataset['Total']/300) * 100
student_dataset.head(1000)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total  \
# ...

# %%
#Assigning Grades(in CBSE pattern) according to percentage

def assign_grade(percentage):
    if percentage >= 81 and percentage <= 100:
        return 'Grade A'
    elif percentage >= 61 and percentage < 81:
        return 'Grade B'
    elif percentage >= 41 and percentage < 61:
        return 'Grade C'
    elif percentage >= 33 and percentage < 41:
        return 'Grade D'
    elif percentage >= 0 and percentage < 33:
        return 'Grade E'
    
student_dataset['Grades'] = student_dataset['Percentage'].apply(assign_grade)
student_dataset.head(1000)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total  \
# ...

# %%
student_dataset.columns.tolist()
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course',
#  'math score',
#  'reading score',
#  'writing score',
#  'Total',
#  'Percentage',
#  'Grades']

# %%
student_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
#  8   Total                        1000 non-null   int64
#  9   Percentage                   1000 non-null   float64
#  10  Grades                       1000 non-null   object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 86.1+ KB

# %% [markdown]
# So there are no null records in the dataset.

# %%
student_dataset.describe()
# Out:
#        math score  reading score  writing score        Total   Percentage
# count  1000.00000    1000.000000    1000.000000  1000.000000  1000.000000
# mean     66.08900      69.169000      68.054000   203.312000    67.770667
# std      15.16308      14.600192      15.195657    42.771978    14.257326
# min       0.00000      17.000000      10.000000    27.000000     9.000000
# 25%      57.00000      59.000000      57.750000   175.000000    58.333333
# 50%      66.00000      70.000000      69.000000   205.000000    68.333333
# 75%      77.00000      79.000000      79.000000   233.000000    77.666667
# max     100.00000     100.000000     100.000000   300.000000   100.000000

# %% [markdown]
# It shows the statistics of the dataset.
#     It shows us the count of null/non-null observation, mean and standard deviation of all the score, Total & Percentage,
#     minimum and maximum score in math, reading & writing and in Total value & Percentage. Further shows us the 3 quantiles of
#     the data(25%, 50%, 75%).

# %%
#plotting KDE
student_dataset.plot.density()

# %%
plt.title('Grades' , fontsize = 20)
ax5 = student_dataset['Grades'].value_counts().plot.pie(autopct = "%1.1f%%")
ax5.set_ylabel('')
plt.show()

# %% [markdown]
# - Observations: -
#     1.	Large number of students are achieving Grade B followed by Grade C and A.
#     2.	Very few students are failing (i.e. getting Grade E).

# %% [markdown]
# Now let us look some graphs for Grades for more better analysis and understanding.

# %%
plt.title('Grades Vs Ethinicity' , fontsize = 20)
sns.countplot(x = "race/ethnicity" , hue = "Grades" , data = student_dataset)


gr = pd.crosstab(student_dataset['Grades'] , student_dataset['race/ethnicity'] , normalize = 0) #normalized values 
gr.plot.bar(stacked = True)
plt.title('Grades Vs Ethinicity' , fontsize = 20)
plt.show()

# %%
plt.figure(figsize = (30,10))
plt.subplots_adjust(left = 0.125 , bottom = 0.1 , right = 0.9 , top = 0.9 , wspace = 0.5 , hspace = 0.2)

plt.subplot(251)
plt.title('Grades Vs Gender')
sns.countplot(hue = "gender" , x = "Grades" , data = student_dataset)

plt.subplot(252)
plt.title('Grades Vs Lunch')
sns.countplot(hue = "lunch" , x = "Grades" , data = student_dataset)

plt.subplot(253)
plt.title('Grades Vs Test preperation Course')
sns.countplot(hue = "test preparation course" , x = "Grades" , data = student_dataset)

plt.show()

# %% [markdown]
# - Observations: -
#     1.	More number of female students are failing.
#     2.	Student having free/reduced lunch type are having less Grades or Failing. So, Standard lunch type is more
#     preferable.
#     3.	Students who have completed Test preparation course are not Failing and scoring more. So, Test Preparation course are helpful for students.

# %%
plt.title('Grades Vs Parental Level of Education' , fontsize = 20)
sns.countplot(x = "parental level of education" , hue = "Grades" , data = student_dataset)

gr = pd.crosstab(student_dataset['Grades'] , student_dataset['parental level of education'] , normalize = 0) #normalized values 
gr.plot.bar(stacked = True)
plt.title('Grades Vs Parental Level of Education' , fontsize = 20)
plt.show()

# %% [markdown]
# - Observations: -
#     1.	Students whose parental level of education is Master’s, Bachelor’s degree are not Failing.
#     2.	Students whose are having Master’s degree are also above Grade D.
#     3.	Students whose parental level of education is some college, high school, or some high school are Failing more.
#
# Students Grades are directly proportional to Parental level of education.
# So, Parental Level of Education also affects the Students Grades.
